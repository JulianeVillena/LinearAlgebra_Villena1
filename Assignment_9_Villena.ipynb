# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianeVillena/LinearAlgebra_Villena1/blob/main/Assignment_9_Villena.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 2 - Plotting Vector using NumPy and MatPlotLib

# %% [markdown]
# In this laboratory we will be discussing the basics of numerical and scientific programming by working with Vectors using NumPy and MatPlotLib.

# %% [markdown]
# ### Objectives
# At the end of this activity you will be able to:
# 1. Be familiar with the libraries in Python for numerical and scientific programming.
# 2. Visualize vectors through Python programming.
# 3. Perform simple vector operations through code.

# %% [markdown]
# ## Discussion

# %% [markdown]
# ### NumPy

# %% [markdown]
# NumPy or Numerical Python, is mainly used for matrix and vector operations. It is capable of declaring computing and representing matrices. Most Python scientific programming libraries uses NumPy as the basic code.

# %% [markdown]
# Scalars \\
# Represent magnitude or a single value
#
# Vectors \\
# Represent magnitude with directors

# %% [markdown]
# #### Representing Vectors

# %% [markdown]
# Now that you know how to represent vectors using their component and matrix form we can now hard-code them in Python. Let's say that you have the vectors:

# %% [markdown]
# $$ A = 4\hat{x} + 3\hat{y} \\
# B = 2\hat{x} - 5\hat{y}\\
# C = 4ax + 3ay - 2az \\
# D = 2\hat{i} - 2\hat{j} + 3\hat{k}$$

# %% [markdown]
# In which it's matrix equivalent is:

# %% [markdown]
# $$ A = \begin{bmatrix} 4 \\ 3\end{bmatrix} , B = \begin{bmatrix} 2 \\ -5\end{bmatrix} , C = \begin{bmatrix} 4 \\ 3 \\  -2 \end{bmatrix}, D = \begin{bmatrix} 2 \\ -2 \\ 3\end{bmatrix}
# $$
# $$ A = \begin{bmatrix} 4 & 3\end{bmatrix} , B = \begin{bmatrix} 2 & -5\end{bmatrix} , C = \begin{bmatrix} 4 & 3 & -2\end{bmatrix} , D = \begin{bmatrix} 2 & -2 & 3\end{bmatrix}
# $$

# %% [markdown]
# We can then start doing numpy code with this by:

# %%
## Importing necessary libraries
import numpy as np ## 'np' here is short-hand name of the library (numpy) or a nickname.

# %%
A = np.array([4, 3])
B = np.array([2, -5])
C = np.array([
              [4],
              [3],
              [-2]
])
D = np.array ([[2],
              [-2],
              [3]])
print('Vector A is ', A)
print('Vector B is ', B)
print('Vector C is ', C)
print('Vector D is ', D)
# Out:
# Vector A is  [4 3]
# Vector B is  [ 2 -5]
# Vector C is  [[ 4]
#  [ 3]
#  [-2]]
# Vector D is  [[ 2]
#  [-2]
#  [ 3]]

# %% [markdown]
# #### Describing vectors in NumPy

# %% [markdown]
# Describing vectors is very important if we want to perform basic to advanced operations with them. The fundamental ways in describing vectors are knowing their shape, size and dimensions.

# %%
### Checking shapes
### Shapes tells us how many elements are there on each row and column

A.shape
H = np.array([1, 0, 2, 5, -0.2, 0])
H.shape
C.shape
# Out:
# (3, 1)

# %%
### Checking size
### Array/Vector sizes tells us many total number of elements are there in the vector

D.size
# Out:
# 3

# %%
### Checking dimensions
### The dimensions or rank of a vector tells us how many dimensions are there for the vector.

D.ndim
# Out:
# 2

# %% [markdown]
# Great! Now let's try to explore in performing operations with these vectors.

# %% [markdown]
# #### Addition

# %% [markdown]
# The addition rule is simple, the we just need to add the elements of the matrices according to their index. So in this case if we add vector $A$ and vector $B$ we will have a resulting vector:

# %% [markdown]
# $$R = 6\hat{x}-2\hat{y} \\ \\or \\ \\ R = \begin{bmatrix} 6 \\ -2\end{bmatrix} $$

# %% [markdown]
# So let's try to do that in NumPy in several number of ways:

# %%
R = np.add(A, B) ## this is the functional method usisng the numpy library
P = np.add(C, D)

# %%
R = A + B   ## this is the explicit method, since Python does a value-reference so it can 
            ## know that these variables would need to do array operations.
R
# Out:
# array([ 6, -2])

# %%
pos1 = np.array([0,0,0])
pos2 = np.array([0,1,3])
pos3 = np.array([1,5,-2])
pos4 = np.array([5,-3,3])
#R = pos1 + pos2 + pos3 + pos4
#R = np.multiply(pos3, pos4)
R = pos3 / pos4
R
# Out:
# array([ 0.2       , -1.66666667, -0.66666667])

# %% [markdown]
# ##### Try for yourself!

# %% [markdown]
# Try to implement subtraction, multiplication, and division with vectors $A$ and $B$!

# %% [markdown]
# $$ A = \begin{bmatrix} 4 \\ 3\end{bmatrix} , B = \begin{bmatrix} 2 \\ -5\end{bmatrix}
# $$

# %%
A1 = np.array([
              [4],
              [3]
])
B2 = np.array ([
              [2],
              [-5]
])

# %%
C1 = np.add(A1, B2)
C1
# Out:
# array([[ 6],
#        [-2]])

# %%
C1 = np.subtract(A1, B2)
C1
# Out:
# array([[2],
#        [8]])

# %%
C1 = np.multiply(A1, B2)
C1
# Out:
# array([[  8],
#        [-15]])

# %%
C1 = np.divide(A1, B2)
C1
# Out:
# array([[ 2. ],
#        [-0.6]])

# %% [markdown]
# ### Scaling

# %% [markdown]
# Scaling or scalar multiplication takes a scalar value and performs multiplication with a vector. Let's take the example below:

# %% [markdown]
# $$S = 5 \cdot A$$

# %% [markdown]
# We can do this in numpy through:

# %%
#S = 5 * A
S = np.multiply(5,A)
S
# Out:
# array([20, 15])

# %% [markdown]
# Try to implement scaling with two vectors.

# %%
S1 = np.multiply(5,A1)
S1
# Out:
# array([[20],
#        [15]])

# %%
S2 = np.multiply(5,B2)
S2
# Out:
# array([[ 10],
#        [-25]])

# %% [markdown]
# ### MatPlotLib

# %% [markdown]
# MatPlotLib or MATLab Plotting library is Python's take on MATLabs plotting feature. MatPlotLib can be used vastly from graping values to visualizing several dimensions of data.

# %% [markdown]
# #### Visualizing Data

# %% [markdown]
# It's not enough just solving these vectors so might need to visualize them. So we'll use MatPlotLib for that. We'll need to import it first.

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
A = [1, -1]
B = [5, -1]
plt.scatter(A[0], A[1], label='A', c='green')
plt.scatter(B[0], B[1], label='B', c='magenta')
plt.grid()
plt.legend()
plt.show()

# %%
A = np.array([1, -1])
B = np.array([1, 5])
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.quiver(0, 0, A[0], A[1], angles='xy', scale_units='xy', scale=1, color='red')
plt.quiver(A[0], A[1], B[0], B[1], angles='xy', scale_units='xy', scale=1, color='green')
R = A + B
plt.quiver(0, 0, R[0], R[1], angles='xy', scale_units='xy', scale=1, color='black')
plt.grid()
plt.show()
print(R)
Slope = R[1]/R[0]
print(Slope)
Angle = (np.arctan(Slope))*(180/np.pi)
print(Angle)
# Out:
# [2 4]
# 2.0
# 63.43494882292201

# %%
n = A.shape[0]
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.quiver(0,0, A[0], A[1], angles='xy', scale_units='xy',scale=1)
plt.quiver(A[0],A[1], B[0], B[1], angles='xy', scale_units='xy',scale=1)
plt.quiver(0,0, R[0], R[1], angles='xy', scale_units='xy',scale=1)
plt.show()

# %% [markdown]
# Try plotting Three Vectors and show the Resultant Vector as a result.
# Use Head to Tail Method.

# %%
A = np.array([0, 5])
B = np.array([3, 2])
C = np.array([4, 1])
plt.title("Resultant Vector\nMagnitude:{}")
plt.xlim(-5, 15)
plt.ylim(-5, 15)
plt.quiver(0, 0, A[0], A[1], angles='xy', scale_units='xy', scale=1, color='Red')
plt.quiver(A[0], A[1], B[0], B[1], angles='xy', scale_units='xy', scale=1, color='Orange')
plt.quiver(3, 7, C[0], C[1], angles='xy', scale_units='xy', scale=1, color='yellow')
R = A + B + C
plt.quiver(0, 0, R[0], R[1], angles='xy', scale_units='xy', scale=1, color='black')
plt.grid()
plt.show()
print(R)
Magnitude = np.sqrt(np.sum(R**2))
print(Magnitude)
Slope = R[1]/R[0]
print(Slope)
Angle = (np.arctan(Slope))*(180/np.pi)
print(Angle)
# Out:
# [7 8]
# 10.63014581273465
# 1.1428571428571428
# 48.81407483429035

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Conclusion**

# %% [markdown]
# Therefore, In concnclusion in conducting this laboratory activity, by representing and using Vectors, It was concluded that we students were able to visualized and perform the operations of Vector using Google collaboratory, Hence, becoming much familiar with the basic functions of using mathematical operations of Vector applied into code. Moreover, in declaration of MatPlotlib in order to plot the scalar values and applied the vectors into a graph. By performing the tasks given, the students were able to show the resultant vector of by adding the three vectors using head to tail Method.
