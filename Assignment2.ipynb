# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianeVillena/LinearAlgebra_Villena1/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Welcome to Python Fundamentals***
#  In this module, we are going to establish our skills in Python programming. In this notebook we are going to cover:
#
#  * Variables and Data Types
#  * Operations
#  * Input and Output Operations
#  * Logic Control
#  * Iterables
#  * Functions

# %% [markdown]
# ## **Variables and Data Types** - Variables are used to store the needed values for the data and the values stored may change depending on the needed specifications. While, In data types we can include characters,string,integers, float, complex numbers and boolean, these are used to display letters and numerical number values.
#
# [1] K. L. Busbee and D. Braunschweig, “Data types,” Programming Fundamentals, 15-Dec-2018. [Online]. Available: https://press.rebus.community/programmingfundamentals/chapter/data-types/.
#
# ![2-432x300.png](data:image/png;base64,...)
# ![Python-Variable-Types.png](data:image/png;base64,...)

# %%
x = 1
a, b = 3, -2

# %%
type(x)

# %%
y = 3.0
type(y)

# %%
x = float(x)
type(x)

# %%
s, t, u = "1", "3", 'three'
type(u)

# %% [markdown]
# ## **Operations** are used in functions to Add, Subtract, Multiply, Division,Exponential and etc. (Symbols such as + to add, - to subtract, * to multiply, / to divide and ^ for exponential. Operations are also used to interpret and perform mathematical statements in order to produce the final value of the result.
# [1] Python - basic operators. [Online]. Available: https://www.tutorialspoint.com/python/python_basic_operators.htm.
# ![operations.png](data:image/png;base64,...)

# %% [markdown]
# ### **Arithmetic** or arithmentic operations are commonly used in mathematical calculations, the function contains two operands and perform a calculation wherein it does include operators to be used performing addition, subtraction, multiplication, division and etc.
# [1] Arithmetic operators. [Online]. Available: https://www.iitk.ac.in/esc101/05Aug/tutorial/java/nutsandbolts/arithmetic.html#:~:text=These%20operators%20are%20%2B%20(addition),in%20the%20Java%20programming%20language.
#
#
# ![arithmetic.jpg](data:image/jpeg;base64,...)

# %%
w, x, y, z = 4.0, -3.0, 1, -32

# %%
### Addition
S = w + x

# %%
### Subtraction
D = y - z

# %%
### Multiplication
P = w*z

# %%
### Division
Q = y/x

# %%
### Floor Division
Qf = w//z
Qf
# Out:
# -1.0

# %%
### Exponentiation
E = w**w
E

# %%
### Modulo
mod = z%x
mod

# %% [markdown]
# ### **Assignment** or assignment operators are used to assign values to a variable or a property. These operatos can also be used in logical operations such as bitwise logical operations or operations on integral operands and Boolean operands.
# [1]“Assignment operators in python: Various types of assignment operators,” EDUCBA, 16-Aug-2021. [Online]. Available: https://www.educba.com/assignment-operators-in-python/.
# ![assignment-operator-in-python.jpg](data:image/jpeg;base64,...)

# %%
A, B, C, D, E = 0, 100, 2, 1, 2

# %%
A += w

# %%
B -= x

# %%
C *= w

# %%
D /= x
D

# %%
C **= y
C

# %% [markdown]
# ### **Comparators** are used to take two numbers and compare them, while it compares the values it also produces boolean values that is commonly used in numerical values and data types
# ![ami-2015-python-basics-35-638.webp](data:image/webp;base64,...)

# %%
size_1, size_2, size_3 = 1, 2.0, "1"
true_size = 1.0

# %%
## Equality
size_1 == true_size

# %%
## Non-Equality
size_2 != true_size

# %%
## Inequality
s1 = size_1 > size_2
s2 = size_1 < size_2/2
s3 = true_size >= size_1
s4 = size_2 <= true_size

# %% [markdown]
# ## **Logical** are operators used for conditional statements wether it is true or false. Common logical operators include AND, OR, and NOT.
# “Python tutorial 5: Logical operators,” Python tutorial 5 | Logical Operators - Software Development and Testing Articles, Tutorials and Help Guides. [Online]. Available: https://inderpsingh.blogspot.com/2019/09/PythonTutorial5.html.
# ![LogicalOperators.png](data:image/png;base64,...)

# %%
size_1 == true_size

# %%
size_1 is true_size

# %%
size_1 is not true_size

# %%
p, q = True, False
conj = p and q

# %%
disj = p and q
disj

# %%
nand = not(P and Q)
nand

# %%
xor = (not P and Q) or (P and not Q)
xor
# Out:
# True

# %% [markdown]
# ## **Input and Output** are functions that allows the user to insert values into the program and to display output or the printed values of the program on an output device screen.
# ![python_input_and_output.png](data:image/png;base64,...)

# %%
print("Hello World")

# %%
cnt = 14000

# %%
string = "Hello World"
print(string, ", Current COVID count is:", cnt)
cnt += 10000

# %%
print(f"{string}, current count is; {cnt}")

# %%
sem_grade = 86.25
name = "Jul"
print("Hello {}, your semestral grade is: {}".format(name, sem_grade))
# Out:
# Hello Jul, your semestral grade is: 86.25

# %%
pg, mg, fg = 98, 85, 65
print("The weights of your semestral grades are:\
\n\t {} for Prelims\
\n\t {} for Midterms, and\
\n\t {} for FInals.".format(pg, mg, fg))
# Out:
# The weights of your semestral grades are:
# 	 98 for Prelims
# 	 85 for Midterms, and
# 	 65 for FInals.

# %%
e = input("enter a number:")

# %%
name = input("Enter your name: " )
pg = input("Enter prelim grade: ")
mg = input("Enter midterm grade: ")
fg = input("Enter final grade: ")
sem_grade = None
print("Hello {}, your semestral grade is: {}".format(name, sem_grade))
# Out:
# Enter your name: ju
# Enter prelim grade: 34
# Enter midterm grade: 56
# Enter final grade: 67
# Hello ju, your semestral grade is: None

# %% [markdown]
# ## **Looping Statement** used to satisfy the given function by repeatedly executing a block of statements of a given condition
# ![python_for_loop.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## While is a loop statement wherein we can execute set of statements as long as the condition is true.

# %%
## while loops
i, j = 0, 10
while(i<=j):
print(f"{i}\t|\t{j}")
i += 1

# %%
# for(int = 0) 1<10; 1++{
# printf(i)
# }

i = 0
for i in ranage(11):
  print(i)

# %%
playlist = ["Bahay Kubo", "Magandang Kanta", "Buko"]
print("Now playing:\n")
for song in playlist:
  print(song)
# Out:
# Now playing:
#
# Bahay Kubo
# Magandang Kanta
# Buko

# %% [markdown]
# ## **Flow Control** is a program's control flow is the order in which the program's code executes. Wherein it is regulated by loops, function calls and conditional statements.
# ![python-flow-control-statements.png](data:image/png;base64,...)

# %% [markdown]
# Condition Statements

# %%
num_1,num_2 = 12, 12
if(num_1 == num_2):
  print("HAHA")
elif(num_1>num_2):
  print("HOHO")
else:
  print("HAHA")
# Out:
# HAHA

# %% [markdown]
# ## **Functions** are organized block of code that is used to perform a single or related action. Wherein function helps for modularity for your application and a high degree of code reusing.
# ![download.jpg](data:image/jpeg;base64,...)

# %%
# void DeleteUser (int userid){
#   delete(userid);
#}

def delete_user (userid):
    print("successfully delete userid: {}".format(userid))

# %%
userid= 2020_100100
delete_user(2020_100100)
# Out:
# successfully delete userid: 2020100100

# %%
addend1, addend2 = 5, 6

# %%
def add(addend1, addend2):
    sum = addend1 + addend2
    return sum

# %%
add(5, 4)
# Out:
# 9

# %% [markdown]
# **References:**
#
# [1] K. L. Busbee and D. Braunschweig, “Data types,” Programming Fundamentals, 15-Dec-2018. [Online]. Available: https://press.rebus.community/programmingfundamentals/chapter/data-types/.
#
# [2] Python - basic operators. [Online]. Available: https://www.tutorialspoint.com/python/python_basic_operators.htm.
#
# [3] Arithmetic operators. [Online]. Available: https://www.iitk.ac.in/esc101/05Aug/tutorial/java/nutsandbolts/arithmetic.html#:~:text=These%20operators%20are%20%2B%20(addition),in%20the%20Java%20programming%20language.
#
# [4] “Assignment operators in python,” GeeksforGeeks, 29-Aug-2020. [Online]. Available: https://www.geeksforgeeks.org/assignment-operators-in-python/.
#
# [5] “The secret of comparators: Comparison operators in python,” Python Pool, 29-Jul-2021. [Online]. Available: https://www.pythonpool.com/python-comparators/.
# [6] “Python operators,” DataCamp Community. [Online]. Available: https://www.datacamp.com/community/tutorials/python-operators-tutorial?utm_source=adwords_ppc&amp;utm_campaignid=1455363063&amp;utm_adgroupid=65083631748&amp;utm_device=c&amp;utm_keyword=&amp;utm_matchtype=b&amp;utm_network=g&amp;utm_adpostion=&amp;utm_creative=332602034364&amp;utm_targetid=aud-438999696719%3Adsa-429603003980&amp;utm_loc_interest_ms=&amp;utm_loc_physical_ms=9067330&amp;gclid=Cj0KCQjwkIGKBhCxARIsAINMioIsMdiRZRdXQdff_vyrdsCQ0VbA0mQ-gf0CEiA0da1OQKkS0SrvUacaApdbEALw_wcB.
#
# [7] “Python input, output and import,” Programiz. [Online]. Available: https://www.programiz.com/python-programming/input-output-import.
#
# [8] “Loops in python,” GeeksforGeeks, 12-Nov-2020. [Online]. Available: https://www.geeksforgeeks.org/loops-in-python/#:~:text=In%20python%2C%20while%20loop%20is,loop%20in%20program%20is%20executed.
#
# [9] “What are control flow statements in python?,” Educative. [Online]. Available: https://www.educative.io/edpresso/what-are-control-flow-statements-in-python.
#
# [10] Python functions. [Online]. Available: https://www.w3schools.com/python/python_functions.asp.
